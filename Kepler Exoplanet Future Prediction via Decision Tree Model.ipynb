# %% [markdown]
# # References
# 1. [Data source 2017 (Kaggel)](https://www.kaggle.com/nasa/kepler-exoplanet-search-results)
# 2. [Data source 2021 (NASA)](https://exoplanetarchive.ipac.caltech.edu/cgi-bin/TblView/nph-tblView?app=ExoTbls&config=cumulative)
# 2. [Column explenation (not complete)](https://keplerexoplanets.readthedocs.io/en/latest/dataset.html)
# 3. [Column explenation (from a repo)](https://github.com/bnarath/find_Exoplanet)
# 4. [Column explenation (NASA web)](https://exoplanetarchive.ipac.caltech.edu/docs/API_kepcandidate_columns.html)
# 5. [Exoplanet explenation](https://exoplanets.nasa.gov/what-is-an-exoplanet/overview/)

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np

from sklearn import tree
import graphviz 

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.tree import DecisionTreeClassifier
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, f1_score, roc_auc_score 

sns.set()
# %matplotlib inline

# %%
df = pd.read_csv('cumulative.csv', sep=',')
df.head()
# Out:
#    rowid     kepid kepoi_name   kepler_name koi_disposition koi_pdisposition  \
# 0      1  10797460  K00752.01  Kepler-227 b       CONFIRMED        CANDIDATE
# 1      2  10797460  K00752.02  Kepler-227 c       CONFIRMED        CANDIDATE
# 2      3  10811496  K00753.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 3      4  10848459  K00754.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 4      5  10854555  K00755.01  Kepler-664 b       CONFIRMED        CANDIDATE
#
#    koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  ...  \
# 0      1.000              0              0              0  ...
# 1      0.969              0              0              0  ...
# 2      0.000              0              1              0  ...
# 3      0.000              0              1              0  ...
# 4      1.000              0              0              0  ...
#
#    koi_steff_err2  koi_slogg  koi_slogg_err1  koi_slogg_err2  koi_srad  \
# 0           -81.0      4.467           0.064          -0.096     0.927
# 1           -81.0      4.467           0.064          -0.096     0.927
# 2          -176.0      4.544           0.044          -0.176     0.868
# 3          -174.0      4.564           0.053          -0.168     0.791
# 4          -211.0      4.438           0.070          -0.210     1.046
#
#    koi_srad_err1  koi_srad_err2         ra        dec  koi_kepmag
# 0          0.105         -0.061  291.93423  48.141651      15.347
# 1          0.105         -0.061  291.93423  48.141651      15.347
# 2          0.233         -0.078  297.00482  48.134129      15.436
# 3          0.201         -0.067  285.53461  48.285210      15.597
# 4          0.334         -0.133  288.75488  48.226200      15.509
#
# [5 rows x 50 columns]

# %% [markdown]
# ## Inspect and Explore the Data

# %% [markdown]
# ##### We start with over 9,000 rows

# %%
df.shape
# Out:
# (9564, 50)

# %% [markdown]
# ##### The non-number columns are the names of the KOI (2 columns), the label for each KOI (2 columns) and the TCE delivery name (column 37)¶

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9564 entries, 0 to 9563
# Data columns (total 50 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rowid              9564 non-null   int64
#  1   kepid              9564 non-null   int64
#  2   kepoi_name         9564 non-null   object
#  3   kepler_name        2294 non-null   object
#  4   koi_disposition    9564 non-null   object
#  5   koi_pdisposition   9564 non-null   object
#  6   koi_score          8054 non-null   float64
#  7   koi_fpflag_nt      9564 non-null   int64
#  8   koi_fpflag_ss      9564 non-null   int64
#  9   koi_fpflag_co      9564 non-null   int64
#  10  koi_fpflag_ec      9564 non-null   int64
#  11  koi_period         9564 non-null   float64
#  12  koi_period_err1    9110 non-null   float64
#  13  koi_period_err2    9110 non-null   float64
#  14  koi_time0bk        9564 non-null   float64
#  15  koi_time0bk_err1   9110 non-null   float64
#  16  koi_time0bk_err2   9110 non-null   float64
#  17  koi_impact         9201 non-null   float64
#  18  koi_impact_err1    9110 non-null   float64
#  19  koi_impact_err2    9110 non-null   float64
#  20  koi_duration       9564 non-null   float64
#  21  koi_duration_err1  9110 non-null   float64
#  22  koi_duration_err2  9110 non-null   float64
#  23  koi_depth          9201 non-null   float64
#  24  koi_depth_err1     9110 non-null   float64
#  25  koi_depth_err2     9110 non-null   float64
#  26  koi_prad           9201 non-null   float64
#  27  koi_prad_err1      9201 non-null   float64
#  28  koi_prad_err2      9201 non-null   float64
#  29  koi_teq            9201 non-null   float64
#  30  koi_teq_err1       0 non-null      float64
#  31  koi_teq_err2       0 non-null      float64
#  32  koi_insol          9243 non-null   float64
#  33  koi_insol_err1     9243 non-null   float64
#  34  koi_insol_err2     9243 non-null   float64
#  35  koi_model_snr      9201 non-null   float64
#  36  koi_tce_plnt_num   9218 non-null   float64
#  37  koi_tce_delivname  9218 non-null   object
#  38  koi_steff          9201 non-null   float64
#  39  koi_steff_err1     9096 non-null   float64
#  40  koi_steff_err2     9081 non-null   float64
#  41  koi_slogg          9201 non-null   float64
#  42  koi_slogg_err1     9096 non-null   float64
#  43  koi_slogg_err2     9096 non-null   float64
#  44  koi_srad           9201 non-null   float64
#  45  koi_srad_err1      9096 non-null   float64
#  46  koi_srad_err2      9096 non-null   float64
#  47  ra                 9564 non-null   float64
#  48  dec                9564 non-null   float64
#  49  koi_kepmag         9563 non-null   float64
# dtypes: float64(39), int64(6), object(5)
# memory usage: 3.6+ MB

# %% [markdown]
# ##### Remove the following columns as they don't give us any computational power. We remove the koi_score column because it represents the confidence level that a KOI (Kepler Object of Interest) is a planet.

# %%
df = df.drop(['rowid','kepler_name','koi_pdisposition','koi_score','koi_tce_delivname','koi_teq_err1','koi_teq_err2'], 1)
df.head()
# Out:
#       kepid kepoi_name koi_disposition  koi_fpflag_nt  koi_fpflag_ss  \
# 0  10797460  K00752.01       CONFIRMED              0              0
# 1  10797460  K00752.02       CONFIRMED              0              0
# 2  10811496  K00753.01  FALSE POSITIVE              0              1
# 3  10848459  K00754.01  FALSE POSITIVE              0              1
# 4  10854555  K00755.01       CONFIRMED              0              0
#
#    koi_fpflag_co  koi_fpflag_ec  koi_period  koi_period_err1  koi_period_err2  \
# 0              0              0    9.488036     2.775000e-05    -2.775000e-05
# 1              0              0   54.418383     2.479000e-04    -2.479000e-04
# 2              0              0   19.899140     1.494000e-05    -1.494000e-05
# 3              0              0    1.736952     2.630000e-07    -2.630000e-07
# 4              0              0    2.525592     3.761000e-06    -3.761000e-06
#
#    ...  koi_steff_err2  koi_slogg  koi_slogg_err1  koi_slogg_err2  koi_srad  \
# 0  ...           -81.0      4.467           0.064          -0.096     0.927
# 1  ...           -81.0      4.467           0.064          -0.096     0.927
# 2  ...          -176.0      4.544           0.044          -0.176     0.868
# 3  ...          -174.0      4.564           0.053          -0.168     0.791
# 4  ...          -211.0      4.438           0.070          -0.210     1.046
#
#    koi_srad_err1  koi_srad_err2         ra        dec  koi_kepmag
# 0          0.105         -0.061  291.93423  48.141651      15.347
# 1          0.105         -0.061  291.93423  48.141651      15.347
# 2          0.233         -0.078  297.00482  48.134129      15.436
# 3          0.201         -0.067  285.53461  48.285210      15.597
# 4          0.334         -0.133  288.75488  48.226200      15.509
#
# [5 rows x 43 columns]

# %% [markdown]
# #### Dropped from 50 to 43 columns

# %%
df.shape
# Out:
# (9564, 43)

# %% [markdown]
# #### Dropped from 9564 to 8744 rows

# %%
df = df.dropna()
df.shape
# Out:
# (8744, 43)

# %% [markdown]
# ##### Our goal is to compute if a KOI is or is not a planet. The koi_disposition column has three values which are the following:

# %% [markdown]
# ##### The CONFIRMED KOI are the planets that have passed all the Kepler's test and are verified by NASA's database. The FALSE POSSITIVE KOI is an object which is NOT a planet. The CANDIDATE KOI is a object that has not yet passed all the Kepler's test.

# %%
df['koi_disposition'].value_counts()
# Out:
# FALSE POSITIVE    4358
# CONFIRMED         2272
# CANDIDATE         2114
# Name: koi_disposition, dtype: int64

# %%
condition = df['koi_disposition'] == 'CANDIDATE'
df_candidate = df[condition]
df_candidate.head()
# Out:
#        kepid kepoi_name koi_disposition  koi_fpflag_nt  koi_fpflag_ss  \
# 37  11138155  K00760.01       CANDIDATE              0              0
# 58  11818800  K00777.01       CANDIDATE              0              0
# 62  11918099  K00780.02       CANDIDATE              0              0
# 63   9579641  K00115.03       CANDIDATE              0              0
# 72   3246984  K00799.01       CANDIDATE              0              0
#
#     koi_fpflag_co  koi_fpflag_ec  koi_period  koi_period_err1  \
# 37              0              0    4.959319     5.150000e-07
# 58              0              0   40.419504     1.139000e-04
# 62              0              0    7.240661     1.617000e-05
# 63              0              0    3.435916     4.729000e-05
# 72              0              0    1.626630     1.015000e-06
#
#     koi_period_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 37    -5.150000e-07  ...           -77.0      4.359           0.110
# 58    -1.139000e-04  ...          -163.0      4.507           0.116
# 62    -1.617000e-05  ...           -79.0      4.595           0.012
# 63    -4.729000e-05  ...          -115.0      4.339           0.132
# 72    -1.015000e-06  ...          -172.0      4.410           0.124
#
#     koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 37          -0.110     1.082          0.173         -0.130  292.16705
# 58          -0.105     0.781          0.116         -0.095  294.31686
# 62          -0.064     0.765          0.055         -0.028  293.83331
# 63          -0.108     1.087          0.157         -0.142  287.88733
# 72          -0.186     0.973          0.270         -0.145  294.36819
#
#           dec  koi_kepmag
# 37  48.727589      15.263
# 58  50.080231      15.487
# 62  50.230350      15.334
# 63  46.276241      12.791
# 72  38.310280      15.279
#
# [5 rows x 43 columns]

# %%
name = df_candidate['kepoi_name'].tolist()

# %%
df = df.drop(['kepoi_name'], 1) #if the column is not removed an error happens in the dummy function
df.head()
# Out:
#       kepid koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 0  10797460       CONFIRMED              0              0              0
# 1  10797460       CONFIRMED              0              0              0
# 2  10811496  FALSE POSITIVE              0              1              0
# 3  10848459  FALSE POSITIVE              0              1              0
# 4  10854555       CONFIRMED              0              0              0
#
#    koi_fpflag_ec  koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0              0    9.488036     2.775000e-05    -2.775000e-05   170.538750
# 1              0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 2              0   19.899140     1.494000e-05    -1.494000e-05   175.850252
# 3              0    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 4              0    2.525592     3.761000e-06    -3.761000e-06   171.595550
#
#    ...  koi_steff_err2  koi_slogg  koi_slogg_err1  koi_slogg_err2  koi_srad  \
# 0  ...           -81.0      4.467           0.064          -0.096     0.927
# 1  ...           -81.0      4.467           0.064          -0.096     0.927
# 2  ...          -176.0      4.544           0.044          -0.176     0.868
# 3  ...          -174.0      4.564           0.053          -0.168     0.791
# 4  ...          -211.0      4.438           0.070          -0.210     1.046
#
#    koi_srad_err1  koi_srad_err2         ra        dec  koi_kepmag
# 0          0.105         -0.061  291.93423  48.141651      15.347
# 1          0.105         -0.061  291.93423  48.141651      15.347
# 2          0.233         -0.078  297.00482  48.134129      15.436
# 3          0.201         -0.067  285.53461  48.285210      15.597
# 4          0.334         -0.133  288.75488  48.226200      15.509
#
# [5 rows x 42 columns]

# %%
df_candidate.shape
# Out:
# (2114, 43)

# %% [markdown]
# ##### In this model we will remove the CANDIDATE KOIs (all 2248 of them). Now, we create a dummy table for column 'koi_disposition'.

# %%
df.drop(df[df['koi_disposition'] == 'CANDIDATE'].index, inplace = True)
df = pd.get_dummies(df, 'koi_disposition', drop_first=True)
df.rename(columns = {'koi_disposition_FALSE POSITIVE':'koi_confirmed'}, inplace = True)
df.head()
# Out:
#       kepid  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0  10797460              0              0              0              0
# 1  10797460              0              0              0              0
# 2  10811496              0              1              0              0
# 3  10848459              0              1              0              0
# 4  10854555              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0    9.488036     2.775000e-05    -2.775000e-05   170.538750
# 1   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 2   19.899140     1.494000e-05    -1.494000e-05   175.850252
# 3    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 4    2.525592     3.761000e-06    -3.761000e-06   171.595550
#
#    koi_time0bk_err1  ...  koi_slogg  koi_slogg_err1  koi_slogg_err2  koi_srad  \
# 0          0.002160  ...      4.467           0.064          -0.096     0.927
# 1          0.003520  ...      4.467           0.064          -0.096     0.927
# 2          0.000581  ...      4.544           0.044          -0.176     0.868
# 3          0.000115  ...      4.564           0.053          -0.168     0.791
# 4          0.001130  ...      4.438           0.070          -0.210     1.046
#
#    koi_srad_err1  koi_srad_err2         ra        dec  koi_kepmag  \
# 0          0.105         -0.061  291.93423  48.141651      15.347
# 1          0.105         -0.061  291.93423  48.141651      15.347
# 2          0.233         -0.078  297.00482  48.134129      15.436
# 3          0.201         -0.067  285.53461  48.285210      15.597
# 4          0.334         -0.133  288.75488  48.226200      15.509
#
#    koi_confirmed
# 0              0
# 1              0
# 2              1
# 3              1
# 4              0
#
# [5 rows x 42 columns]

# %%
#koi_confirmed = 1 -> planet
#koi_confirmed = 0 -> false positive

c1 = df['koi_confirmed'] == 0
df['koi_confirmed'] = np.where(c1, 1, 0)
df.head()
# Out:
#       kepid  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0  10797460              0              0              0              0
# 1  10797460              0              0              0              0
# 2  10811496              0              1              0              0
# 3  10848459              0              1              0              0
# 4  10854555              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0    9.488036     2.775000e-05    -2.775000e-05   170.538750
# 1   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 2   19.899140     1.494000e-05    -1.494000e-05   175.850252
# 3    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 4    2.525592     3.761000e-06    -3.761000e-06   171.595550
#
#    koi_time0bk_err1  ...  koi_slogg  koi_slogg_err1  koi_slogg_err2  koi_srad  \
# 0          0.002160  ...      4.467           0.064          -0.096     0.927
# 1          0.003520  ...      4.467           0.064          -0.096     0.927
# 2          0.000581  ...      4.544           0.044          -0.176     0.868
# 3          0.000115  ...      4.564           0.053          -0.168     0.791
# 4          0.001130  ...      4.438           0.070          -0.210     1.046
#
#    koi_srad_err1  koi_srad_err2         ra        dec  koi_kepmag  \
# 0          0.105         -0.061  291.93423  48.141651      15.347
# 1          0.105         -0.061  291.93423  48.141651      15.347
# 2          0.233         -0.078  297.00482  48.134129      15.436
# 3          0.201         -0.067  285.53461  48.285210      15.597
# 4          0.334         -0.133  288.75488  48.226200      15.509
#
#    koi_confirmed
# 0              1
# 1              1
# 2              0
# 3              0
# 4              1
#
# [5 rows x 42 columns]

# %% [markdown]
# ##### Check for duplicated rows and columns that have null values

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Now we are ready to build out Decision Tree Classifier

# %% [markdown]
# ##### The featuers of out model will be all the columns except the id and prediction column respectively the first and last column

# %%
features = df.columns
features = features.delete(0)
features = features.delete(len(features)-1)
print(list(features))
# Out:
# ['koi_fpflag_nt', 'koi_fpflag_ss', 'koi_fpflag_co', 'koi_fpflag_ec', 'koi_period', 'koi_period_err1', 'koi_period_err2', 'koi_time0bk', 'koi_time0bk_err1', 'koi_time0bk_err2', 'koi_impact', 'koi_impact_err1', 'koi_impact_err2', 'koi_duration', 'koi_duration_err1', 'koi_duration_err2', 'koi_depth', 'koi_depth_err1', 'koi_depth_err2', 'koi_prad', 'koi_prad_err1', 'koi_prad_err2', 'koi_teq', 'koi_insol', 'koi_insol_err1', 'koi_insol_err2', 'koi_model_snr', 'koi_tce_plnt_num', 'koi_steff', 'koi_steff_err1', 'koi_steff_err2', 'koi_slogg', 'koi_slogg_err1', 'koi_slogg_err2', 'koi_srad', 'koi_srad_err1', 'koi_srad_err2', 'ra', 'dec', 'koi_kepmag']

# %% [markdown]
# ##### Preparing and seperating the data to be fed to the model
# SMOTE is a technique that addresses the issue of imbalanced classification. In out case, we have twice as much
# FALSE POSITIVE than CONFIRMED KOIs, hence we use SMOTE to synthtically produce new CONFIRMED examples form existing examples. For more information check out this [article](https://machinelearningmastery.com/smote-oversampling-for-imbalanced-classification/).

# %%
X = df[features]
y = df['koi_confirmed']

sm = SMOTE(random_state=42)
X_sm, y_sm = sm.fit_resample(X, y)

print('Lenght of our Training data:', X_sm.shape, '\nLength of our Testing data:', y_sm.shape)
print('\nBalance of positive and negative classes (%):')
y_sm.value_counts(normalize=True) * 100
# Out:
# Lenght of our Training data: (8716, 40)
# Length of our Testing data: (8716,)
#
# Balance of positive and negative classes (%):
# 1    50.0
# 0    50.0
# Name: koi_confirmed, dtype: float64

# %% [markdown]
# ##### Creating the model and fitting the data
# We use GridSearchCV to make sure we use the Decision Tree with the best parameters. GridSearchCV takes as input
# a list of different values for the same parameter and returns the model with the best combination.

# %%
# The params is a dictionary.  
# Where the keys are the parameter, 
# and the values are lists of parameter settings to try as values.
params = {
    'criterion' : ['gini', 'entropy'],
    'max_depth': [2, 5, 6, 7 ,8 , 9, 10], 
    'min_samples_split': [2, 10, 20, 30],
    'min_samples_leaf': [1, 10, 20, 30],
         }

# Pass in an empty Decision Tree (empty excluding the random_state).
# The parameter dictionary
# and the scoring you want to optimize for. 
grid_search_cv =  GridSearchCV( 
    estimator = DecisionTreeClassifier(), 
    param_grid = params, 
    scoring = 'f1')


# Now, with one easy command, fit all combination of trees. 
grid_search_cv.fit(X_sm, y_sm)

# Print the best parameters it found
print(grid_search_cv.best_params_)

# This command gives you the best tree
model = grid_search_cv.best_estimator_
# Out:
# {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 10, 'min_samples_split': 10}

# %%
# Now lets evaluate our model

X_test_c = df_candidate[features]
y_pred = model.predict(X_test_c)

# %% [markdown]
# Create a data frame with the id, name and the prediction about the KOI.

# %%
id_list = df_candidate['kepid'].tolist()
name_list = name
pred_list = list(y_pred)
list_of_tuples = list(zip(id_list, name_list, pred_list))
df_pred = pd.DataFrame(list_of_tuples, columns = ['id', 'name', 'prediction'])

# %%
df_pred.head()
# Out:
#          id       name  prediction
# 0  11138155  K00760.01           1
# 1  11818800  K00777.01           1
# 2  11918099  K00780.02           0
# 3   9579641  K00115.03           1
# 4   3246984  K00799.01           1

# %% [markdown]
# This data frame is the most updated database as of May 26th fetched from NASA's website about the exoplantes.
# Since the training data is from 2017, we use this table to check how our classifier performed.

# %%
latest_df = pd.read_csv('final-data.csv', sep=',')
latest_df.head()
# Out:
#    rowid     kepid kepoi_name    kepler_name koi_disposition koi_vet_stat  \
# 0      1  11446443  K00001.01     Kepler-1 b       CONFIRMED         Done
# 1      2  10666592  K00002.01     Kepler-2 b       CONFIRMED         Done
# 2      3  10748390  K00003.01     Kepler-3 b       CONFIRMED         Done
# 3      4   3861595  K00004.01  Kepler-1658 b       CONFIRMED         Done
# 4      5   8554498  K00005.01            NaN       CANDIDATE         Done
#
#   koi_vet_date koi_pdisposition  koi_score  koi_fpflag_nt  ...  \
# 0      8/16/18        CANDIDATE        NaN              0  ...
# 1      8/16/18        CANDIDATE        NaN              0  ...
# 2      8/16/18        CANDIDATE        NaN              0  ...
# 3      8/16/18        CANDIDATE        NaN              0  ...
# 4      8/16/18        CANDIDATE        NaN              0  ...
#
#    koi_dicco_mdec  koi_dicco_mdec_err  koi_dicco_msky koi_dicco_msky_err  \
# 0             NaN                 NaN             NaN                NaN
# 1             NaN                 NaN             NaN                NaN
# 2             NaN                 NaN             NaN                NaN
# 3             NaN                 NaN             NaN                NaN
# 4             NaN                 NaN             NaN                NaN
#
#    koi_dikco_mra  koi_dikco_mra_err  koi_dikco_mdec  koi_dikco_mdec_err  \
# 0            NaN                NaN             NaN                 NaN
# 1            NaN                NaN             NaN                 NaN
# 2            NaN                NaN             NaN                 NaN
# 3            NaN                NaN             NaN                 NaN
# 4            NaN                NaN             NaN                 NaN
#
#    koi_dikco_msky  koi_dikco_msky_err
# 0             NaN                 NaN
# 1             NaN                 NaN
# 2             NaN                 NaN
# 3             NaN                 NaN
# 4             NaN                 NaN
#
# [5 rows x 141 columns]

# %% [markdown]
# Get only these three columns.

# %%
latest_df = latest_df[['kepid', 'kepoi_name', 'koi_disposition']]
latest_df.head()
# Out:
#       kepid kepoi_name koi_disposition
# 0  11446443  K00001.01       CONFIRMED
# 1  10666592  K00002.01       CONFIRMED
# 2  10748390  K00003.01       CONFIRMED
# 3   3861595  K00004.01       CONFIRMED
# 4   8554498  K00005.01       CANDIDATE

# %%
latest_df['koi_disposition'].value_counts()
# Out:
# FALSE POSITIVE    4840
# CANDIDATE         2366
# CONFIRMED         2358
# Name: koi_disposition, dtype: int64

# %% [markdown]
# In the proceeding code snippet, we count the correct and incorrect prediction our model made. We also count the KOIs which are still undergoing investigation.

# %%
true_label = 0
true_list = list()
false_label = 0
false_list = list()
no_label = 0

predictions = df_pred['name'].tolist()
for name in predictions:
    cond1 = latest_df['kepoi_name'] == name
    cond2 = df_pred['name'] == name
    
    truth = latest_df.loc[cond1, ['koi_disposition']].koi_disposition.item()
    our_pred = df_pred.loc[cond2, ['prediction']].prediction.item()
    
    if truth == 'CONFIRMED':
        if our_pred == 1:
            true_label = true_label + 1
            true_list.append(name)
        elif our_pred == 0:
            false_label = false_label + 1
            false_list.append(name)
    elif truth == 'FALSE POSITIVE':
        if our_pred == 1:
            false_label = false_label + 1
            false_list.append(name)
        elif our_pred == 0:
            true_label = true_label + 1
            true_list.append(name)
    else:
        no_label = no_label + 1

# %%
print(true_label)
# Out:
# 115

# %%
print(true_list)
# Out:
# ['K00892.02', 'K00145.01', 'K00977.01', 'K01075.01', 'K00945.01', 'K00945.02', 'K01165.01', 'K01311.01', 'K01448.01', 'K01296.01', 'K01563.03', 'K01230.01', 'K01738.01', 'K01747.01', 'K00182.01', 'K01470.01', 'K01539.01', 'K01475.02', 'K01541.01', 'K01545.01', 'K01705.01', 'K01599.01', 'K01892.01', 'K01984.01', 'K02066.01', 'K01928.01', 'K01783.01', 'K01863.01', 'K01822.01', 'K01889.02', 'K02106.01', 'K02120.01', 'K02132.01', 'K02293.01', 'K02076.01', 'K02229.01', 'K02559.01', 'K02417.01', 'K02504.01', 'K02588.01', 'K00004.01', 'K00252.01', 'K02398.01', 'K02626.01', 'K02849.01', 'K02871.01', 'K02878.01', 'K02733.01', 'K02755.01', 'K02757.01', 'K00367.01', 'K00326.01', 'K00326.02', 'K03048.01', 'K00280.01', 'K00347.01', 'K00349.01', 'K00555.02', 'K00089.02', 'K00547.03', 'K00691.01', 'K00650.01', 'K00619.01', 'K04054.01', 'K04386.01', 'K02433.03', 'K04550.01', 'K03520.01', 'K01781.03', 'K03572.01', 'K03361.01', 'K03680.01', 'K03681.02', 'K03849.01', 'K03864.01', 'K03890.01', 'K01807.01', 'K01714.01', 'K01729.01', 'K03933.01', 'K04014.01', 'K01943.01', 'K01783.02', 'K01599.02', 'K03478.01', 'K05047.01', 'K05220.01', 'K04988.01', 'K05129.01', 'K05132.01', 'K05543.01', 'K05449.01', 'K05708.01', 'K05353.01', 'K05752.01', 'K06016.01', 'K06230.01', 'K06250.01', 'K00351.07', 'K06619.01', 'K07446.01', 'K07198.01', 'K07331.01', 'K06941.01', 'K07131.01', 'K07410.01', 'K07599.01', 'K07100.01', 'K06715.01', 'K07045.01', 'K05323.01', 'K06156.01', 'K02802.01', 'K00929.02', 'K03191.02']

# %%
false_label
# Out:
# 87

# %%
no_label
# Out:
# 1912

# %%
1912 + 87 + 115
# Out:
# 2114

# %%
df_candidate['kepid'].count()
# Out:
# 2114

# %% [markdown]
# ## Results
# The calssifier has correctly predicted the outcome of a KOI (either CONFIRMED or FLASE POSITIVE) 115 times. This means that by using the data from 2017, we were able to predict the future correclty 115 times.

# %%
#The model is confident over 89% of the time
X_test_cc = df_candidate[features]
y_pred_proba = model.predict_proba(X_test_cc)[:,1]
count = 0
for i in y_pred_proba:
    if i > 0.6:
        count = count + 1
print(count)
# Out:
# 1893

# %% [markdown]
# #### Visualizing the Decision Tree

# %%
dot_data = tree.export_graphviz(model, out_file=None, 
                     feature_names=features,
                     class_names='koi_confimed',
                     filled=True, rounded=True,  
                     special_characters=True)  
graph = graphviz.Source(dot_data)  
graph.render()
graph

# %%
# Now lets look at our feature importances
my_dict = {'feature_importance': model.feature_importances_,
           'feature':features }
feature_imp = pd.DataFrame.from_dict( my_dict ).sort_values('feature_importance', ascending=False)
feature_imp.head(10)
# Out:
#     feature_importance          feature
# 29            0.307505   koi_steff_err1
# 2             0.248968    koi_fpflag_co
# 0             0.169565    koi_fpflag_nt
# 19            0.122107         koi_prad
# 1             0.087094    koi_fpflag_ss
# 3             0.051919    koi_fpflag_ec
# 26            0.005584    koi_model_snr
# 6             0.003153  koi_period_err2
# 7             0.001505      koi_time0bk
# 37            0.000943               ra

# %%
g=sns.pairplot(
    df,
    hue="koi_confirmed",
    x_vars=["koi_slogg"],
    y_vars=["koi_srad"]
)
g.fig.set_size_inches(10,10)
g._legend.remove()
